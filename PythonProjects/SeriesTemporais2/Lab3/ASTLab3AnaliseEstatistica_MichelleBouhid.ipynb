# %% [markdown]
# ### <font color=darkred> <b> Análise Estatística Para Data Science com Linguagem Python </b> </font>
#
# ### <font color=darkblue> <b> Modelagem Estatística de Séries Temporais </b> </font>
#
# ### <font color=darkgreen> <b> Lab 3 -  Modelagem Preditiva - Forecasting </b> </font>
#
# #### <font color=darkblue> <b> Analise de Correlação X Causalidade em Séries Temporais </b> </font>

# %% [markdown]
# Correlação e covariância são duas medidas estatísticas usadas para determinar o grau de dependência entre duas variáveis.
#
# Ambas indicam a direção da relação linear entre as variáveis, mas diferem na maneira como expressam a força dessa relação.
#
# **A covariância** é uma medida que indica o grau de mudança conjunta entre duas variáveis. Quando as variáveis aumentam ou diminuem juntas (isto é, se movem na mesma direção), a covariância é positiva. Quando uma variável aumenta enquanto a outra diminui (isto é, se movem em direções opostas), a covariância é negativa. Em  palavras,  a  covariância  é  a  média  dos  produtos  dos  desvios  de  cada  variável  em relação à sua média. Fórmula da Covariância:
#
# ![image.png](attachment:image.png)
#
# **A correlação**, por outro lado, não só mostra a direção da relação entre as variáveis, como a covariância, mas também sua força. A correlação é a covariância normalizada, o que significa que os valores da correlação variam entre -1 e 1.
#
# Uma correlação de 1 indica uma relação positiva perfeita entre as variáveis, -1 indica uma relação negativa perfeita, e 0 indica que não há relação linear entre as variáveis.
#
# Fórmula da Correlação (coeficiente de correlação de Pearson):
#
# ![image-2.png](attachment:image-2.png)
#
#
# > A principal diferença entre a correlação e a covariância é que a correlação é uma medida padronizada e, portanto, é independente de unidades de medida, enquanto a covariância pode variar amplamente com base nas unidades de medida das variáveis. Por esse motivo, a correlação é geralmente preferida sobre a covariância para entender a relação entre duas variáveis.

# %% [markdown]
# ### <font color=darkgreen> <b> Correlação no Contexto das Séries Temporais</b> </font>
#
#
# Correlação em séries temporais é usada para entender a dependência entre diferentes pontos de tempo em uma série.
#
# Na análise de séries temporais, esta é uma técnica comumente utilizada para identificar a relação entre os pontos de dados em diferentes momentos.Há dois tipos principais de correlações em séries temporais:
#
# - **Autocorrelação:** A autocorrelação, também conhecida como correlação serial, refere-se à correlação de uma série temporal com uma cópia atrasada de si mesma. Basicamente, compara uma série de dados ao longo do tempo com outra série do mesmo conjunto de dados deslocada ao  longo  do  tempo.  A  autocorrelação  é  usada  para  identificar  padrões  repetitivos  ou sazonalidade em dados de séries temporais.
#
#
# - **Correlação Cruzada:** A correlação cruzada é uma medida da similaridade entre duas séries temporais em diferentes deslocamentos ou lags. É útil para encontrar padrões repetitivos ou para identificar atrasos entre duas séries temporais (por exemplo, a correlação cruzada de uma série temporal de vendas e uma série temporal de publicidade pode mostrar o atraso entre a publicidade e o aumento resultante nas vendas).
#
# É importante notar que a correlação, seja autocorrelação ou correlação cruzada, mede a **relação  linear**  entre  dois  conjuntos  de  dados. **Se  uma  relação  não  linear  estiver  presente,  a correlação pode subestimar a força da relação.**
#
# Finalmente, a correlação em séries temporais deve ser tratada com cuidado, pois muitas séries temporais são autocorrelacionadas. Isso significa que um valor em um ponto no tempo está  correlacionado  com  valores  em  pontos  de  tempo  anteriores.
#
# **Isso  pode  levar  a  um superestimado nível de significância na correlação calculada.** Para evitar esse problema, muitas vezes é apropriado usar testes de correlação que levam em conta a estrutura de autocorrelação, ou pré-processar os dados para remover a autocorrelação antes de calcular as correlações.

# %% [markdown]
# ### <font color=darkred> <b> Instalando e Carregando Pacotes </b> </font>

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.13

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install -U nome_pacote

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
# !pip install nome_pacote==versão_desejada

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook.

# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# !pip install -q -U watermark

# %%
# Imports
import pandas as pd
import numpy as np

# Filtrando warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Michelle Bouhid" --iversions
# Out:
# Author: Michelle Bouhid
#
# numpy : 1.23.5
# pandas: 1.5.3

# %% [markdown]
# ## <font color=darkgreen> <b> Análise de Correlação em Séries Temporais - Análise de Defasagens</b> </font>
# A análise de defasagens, também conhecida como **análise de lag**, é uma técnica importante na análise de séries temporais para entender a dependência temporal entre diferentes lags. Por se tratar de uma unica variável, ela se correlaciona (ou não) com ela mesma em peridos diferentes!! :)
#
# Podemos tambem comparar series diferentes!
#
# Na análise de séries temporais, o termo "lag" é frequentemente usado para se referir a observações passadas em um período de tempo específico. Por exemplo, em um conjunto de dados diários, lag 1 seria o dia anterior, lag 2 seria dois dias antes e assim por diante.
#
# A análise de lag é uma forma de analisar como a correlação entre uma variável e sua própria versão atrasada (lag) varia ao longo do tempo. Isto é frequentemente feito usando autocorrelação e autocorrelação parcial.
#
# **Autocorrelação**: A autocorrelação **mede a relação linear entre uma observação e suas observações anteriores**. Um gráfico de autocorrelação (ou correlograma) pode ser usado para visualizar essa relação. As barras no gráfico representam o coeficiente de **correlação entre a série temporal e ela mesma com lags.**
#
# **Autocorrelação parcial**: A autocorrelação parcial é uma medida da relação entre uma observação e seus lags, **controlando a relação com todos os lags intermediários**. O gráfico de autocorrelação parcial (PACF) pode ser útil para identificar a ordem de um modelo autoregressivo (AR), uma ferramenta comum em análise de séries temporais.
#
# A análise de lag é útil para identificar padrões temporais em séries temporais, como tendências ou sazonalidade. Ela também é uma etapa importante na construção de modelos preditivos para séries temporais, como modelos ARIMA.

# %% [markdown]
# <font color=darkred> <b> No exemplo abaixo criaremos uma série temporal que tem uma tendência ascendente com algum ruído. A função de autocorrelação (ACF) mostra a autocorrelação para diferentes lags e a função de autocorrelação parcial (PACF) mostra a autocorrelação para um dado lag controlando as autocorrelações para todos os lags menores. </b> </font>

# %%
# Imports
import pandas as pd
import numpy as np
import statsmodels
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Michelle Bouhid" --iversions
# Out:
# Author: Michelle Bouhid
#
# matplotlib : 3.7.1
# numpy      : 1.23.5
# statsmodels: 0.13.2
# pandas     : 1.5.3

# %% [markdown]
# ### <font color=darkred> <b> Criando uma Série Temporal </b> </font>

# %%
# Criando uma série temporal com tendência
np.random.seed(0)
n = 100  # número de pontos de dados
x = np.linspace(0, 10, n)
y = x + np.random.normal(0, 1, n)

# %%
# Visualizando a série temporal
plt.figure(figsize = (10, 4))
plt.plot(y)
plt.title('Série Temporal de Exemplo')
plt.show()

# %%
# Calculando e plotando a função de autocorrelação (ACF)
plt.figure(figsize = (10, 4))
# Indica valor da série que é y, no nosso caso e define os lags.
plot_acf(y, lags = 20)
plt.title('Função de Autocorrelação')
plt.show()

# %% [markdown]
# **Gráfico** - barrinhas fora da área sombreada, indicam correlação. Mesmo tendo um valor difernete de zero nas barras, não são estatisticamente representativas porque ficam dentro do intervalo de confiança.
#
# Eixo X, nº de lags e Eixo Y, mede a correlação, então a barra maior do lado esquerdo é a lag1.
# Claramente existe uma forte autocorrelação da série com a lag 1, ié, seu atraso em 1 ponto no tempo, está próximo de 1.
# Observe a 2ª barrinha, existe forte correlação da série com a lag 2...
#
# Por volta da lag 10 as barrinhas já ficam dentro da área sombreada indicando que não há autocorrelação
#
# Portanto, observamos que a série temporal tem autocorrelação com seus valores mais recentes, mas não tem auto correlação com os valores mais distantes no tempo!! Indicando que essa série não é aleatória.
#
# Para usar modelagem Estatistica precisamos que a serie nao seja aleatoria, precisamos detectar padrões

# %% [markdown]
# **Área Sombreada**
#
# A área sombreada representa os intervalos de confiança para os coeficientes de autocorrelação. Tipicamente, os intervalos de confiança são construídos para um nível de confiança de 95%. Isso significa que:
#
# - Se uma barra está dentro da área sombreada, a autocorrelação para aquele lag não é significativamente diferente de zero ao nível de confiança de 95%.
# - Se uma barra está fora da área sombreada, a autocorrelação para aquele lag é significativamente diferente de zero ao nível de confiança de 95%.

# %%
# Calculando e plotando a função de autocorrelação parcial (PACF)
plt.figure(figsize = (10, 4))
plot_pacf(y, lags = 20)
plt.title('Função de Autocorrelação Parcial')
plt.show()

# %% [markdown]
# **Gráfico ACF** mostra uma autocorrelação significativa em muitos lags, o que é esperado de uma série temporal com uma tendência.
#
# **O gráfico PACF**, por outro lado, mostra uma autocorrelação significativa apenas no lag 1, porque a correlação em lags maiores é explicada pelo lag 1. Na área sombreada estão os lags que tem autocorrelação mais fraca.
#
# - ACF (Função de Autocorrelação): Mede a correlação entre a série temporal e seus próprios valores defasados, incluindo todas as correlações intermediárias.
#
# - PACF (Função de Autocorrelação Parcial): Mede a correlação entre a série temporal e seus próprios valores defasados, **removendo o efeito das correlações intermediárias.**

# %% [markdown]
# ## Análise de Correlação em Séries Temporais - Função de Autocorrelação
#
# A Função de Autocorrelação (ACF) é uma ferramenta estatística usada para identificar qualquer autocorrelação na série temporal. A autocorrelação é a correlação de uma série temporal com sua própria versão deslocada. (série temporal univariada)
#
# A função de autocorrelação fornece correlações de uma série com seus próprios valores passados, diferindo por vários lags. As correlações para diferentes lags ajudam a identificar padrões na série temporal.
#
# A função de autocorrelação pode ser representada visualmente em um gráfico de autocorrelação. **No gráfico, o eixo x representa o tamanho do lag e o eixo y representa a força da autocorrelação.** Se a série temporal é aleatória, a maioria das autocorrelações para lags maiores que zero será próxima de zero. Se a série temporal não é aleatória, então uma ou mais das autocorrelações serão significativamente diferentes de zero.
#
# Por exemplo, em uma série temporal onde os valores aumentam ao longo do tempo (tendência), veríamos autocorrelações significativamente positivas em lags iniciais. E se uma série temporal é periódica, veríamos picos em lags no período da série.
#
# A função de autocorrelação é uma ferramenta importante para entender os padrões em uma série temporal e é frequentemente usada na identificação de modelos apropriados para a análise de séries temporais. Por exemplo, ela é usada na seleção do termo MA (média móvel) no modelo ARIMA (Modelo Autoregressivo Integrado de Média Móvel).

# %%
# Imports
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Michelle Bouhid" --iversions
# Out:
# Author: Michelle Bouhid
#
# matplotlib : 3.7.1
# numpy      : 1.23.5
# seaborn    : 0.11.2
# statsmodels: 0.13.2
# pandas     : 1.5.3

# %%
# Vamos criar alguns dados de ações fictícias, para fins didáticos
np.random.seed(0)
dates = pd.date_range(start = '2021-01-01', end = '2024-01-01', freq = 'B')  # dias úteis
prices = np.random.normal(1.0, 0.03, len(dates)).cumprod()  # preços aleatórios
df = pd.DataFrame(data = prices, index = dates, columns = ['Close'])

# %% [markdown]
# Código: np.random.normal(1.0, 0.03, len(dates)): Gera uma série de números aleatórios com distribuição normal, média 1.0 e desvio padrão 0.03, para o número de datas geradas.
#
# .cumprod(): Calcula o produto cumulativo desses números, criando um padrão crescente.
#
# **Como o Código Cria uma Série com Padrão**
#
# Produto Cumulativo (cumprod):
#
# A utilização do método cumprod no array de números aleatórios gera uma série temporal que cresce ao longo do tempo. Cada valor é o produto cumulativo dos valores anteriores, introduzindo uma tendência de crescimento na série.
# Isso simula um comportamento típico de preços de ações, onde há uma tendência geral de crescimento (embora com flutuações aleatórias diárias).
# Distribuição Normal:
#
# Os preços diários são baseados em uma distribuição normal centrada em 1.0 com um desvio padrão pequeno (0.03). Isso significa que, em média, o preço do dia seguinte será aproximadamente 1.0 vezes o preço do dia atual, com pequenas variações.

# %%
# Visualizando os primeiros registros - série univariada - só temos a caluno close
print(df.head())
# Out:
#                Close
# 2021-01-01  1.052922
# 2021-01-04  1.065562
# 2021-01-05  1.096849
# 2021-01-06  1.170586
# 2021-01-07  1.236171

# %%
# Visualizando os últimos registros
print(df.tail())
# Out:
#                Close
# 2023-12-26  0.138170
# 2023-12-27  0.131404
# 2023-12-28  0.131139
# 2023-12-29  0.136998
# 2024-01-01  0.139141

# %%
# Estamos interessados na correlação do dia com o dia anterior
# Chamou a coluna close no df
lag = 1  # ponto anterior no tempo, pq a serie é de d.u.
autocorrelation = df['Close'].autocorr(lag)
print(f'Autocorrelação com lag {lag}: {autocorrelation}')
# Out:
# Autocorrelação com lag 1: 0.9984259031765882

# %% [markdown]
# ## Interpretando as Funções de Autocorrelação
#
# Interpretar as funções de autocorrelação (ACF) e autocorrelação parcial (PACF) é uma habilidade chave para entender a dinâmica de uma série temporal e, portanto, para modelar e prever séries temporais.
#
# **ACF (Autocorrelation Function)**
#
# Um gráfico de autocorrelação (ACF) mostra a correlação de uma série temporal com seus próprios lags. Cada barra do gráfico representa a correlação entre a série temporal original e a versão da série temporal deslocada por um número específico de lags.
#
# Por exemplo, a barra no lag 1 é a correlação entre a série temporal original e a versão da série temporal deslocada por 1 período. As barras que se estendem além da área sombreada (intervalo de confiança) indicam correlações que são estatisticamente significativas.

# %%
# ACF
plot_acf(df['Close'], lags = 50)
plt.show()

# %% [markdown]
# ## Interpretando as Funções de Autocorrelação
#
# **PACF (Partial Autocorrelation Function)**
#
# A função de autocorrelação parcial (PACF) mede a correlação entre uma observação e seu lag, removendo os efeitos de quaisquer correlações devido aos termos em lags intermediários. Por exemplo, a PACF no lag 3 é a correlação entre a série temporal original e a versão da série temporal deslocada por 3 períodos, depois de remover as correlações devido aos lags 1 e 2.
#
# As barras que se estendem além da área sombreada no gráfico PACF também indicam correlações que são estatisticamente significativas.

# %%
# Calculando e plotando a função de autocorrelação parcial (PACF)
plt.figure(figsize = (10, 4))
plot_pacf(df['Close'], lags = 50)
plt.title('Função de Autocorrelação Parcial')
plt.show()

# %% [markdown]
# Os gráficos ACF e PACF são utilizados para identificar os termos apropriados para incluir em modelos autoregressivos (AR), modelos de média móvel (MA) ou modelos ARIMA.
#
# Em um modelo AR(p), esperamos que o gráfico PACF corte após p lags e que o gráfico ACF diminua gradualmente.
#
# Em um modelo MA(q), esperamos que o gráfico ACF corte após q lags e que o gráfico PACF diminua gradualmente.
#
# Em um modelo ARIMA, os padrões podem ser mais complexos devido à combinação de termos AR e MA.
#
# Outros fatores como a estacionariedade da série temporal e a sazonalidade também devem ser levados em conta ao modelar séries temporais.

# %% [markdown]
# ## <font color=darkred> <b> Análise de Causalidade em Séries Temporais </b> </font>

# %% [markdown]
# Para analisar a causalidade em séries temporais, podemos usar o teste de causalidade de Granger. Vamos utilizar a biblioteca statsmodels para realizar este teste.
#
# Apenas para esclarecer, é importante notar que o teste de causalidade de Granger não testa causalidade no sentido tradicional. Em vez disso, ele testa se os valores passados de uma variável ajudam a prever a variável atual além de seus próprios valores passados. Como tal, uma "causa" de Granger pode não ser uma causa no sentido usual da palavra.
#
# Neste exemplo, vamos gerar duas séries temporais aleatórias e então aplicar o teste de causalidade de Granger para ver se uma série "causa a outra".

# %% [markdown]
# No contexto de séries temporais, a causalidade se refere à relação causa-efeito entre duas séries temporais distintas. Ou seja, os valores de uma série (a "causa") influenciam os valores de outra  série  (o  "efeito").
#
# Esta  relação  é  geralmente  medida  usando  testes  estatísticos  que analisam a dependência entre as séries temporais. A análise de causalidade é uma tarefa crucial na modelagem de séries temporais, uma vez que permite identificar os causadores do comportamento de uma série temporal.
#
# Um exemplo clássico de análise de causalidade em séries temporais é a relação entre os preços do petróleo e a inflação. Poderíamos coletar uma série de dados históricos sobre os preços do petróleo e a inflação e tentar determinar se mudanças nos preços do petróleo levam a mudanças na inflação.Existem várias técnicas estatísticas que podemos usar para examinar a causalidade em séries temporais, incluindo testede Granger, modelos de vetores auto-regressivos (VAR), entre outros.
#
# Uma das técnicas mais comuns usadas para investigar a causalidade em séries temporais é o teste de Granger, que usaremos nas aulas a seguir.A causalidade de Granger é um conceito estatístico usado para determinar se uma série temporal é útil na previsão de outra.
#
# Em outras palavras, uma série temporal X causa uma série temporal Y se os valores passados de X fornecem informações significativas sobre os valores futuros de Y, além das informações já contidas nos valores passados de Y. Note que a causalidade de Granger não é a mesma coisa que a causalidade no sentido comum. Se X causa Y, isso não significa que X é a causa de Y. Em vez disso, significa que X é uma previsão útil para Y.
#
# A causalidade de Granger é amplamente utilizada na econometria e em outras áreas para desenvolver modelos de previsão efetivos.Em termos práticos, a causalidade de Granger pode ser testada realizando um teste F em um modelo de regressão. Este teste avalia se os coeficientes associados aos valores passados de X são estatisticamente significativamente diferentes de zero.Entretanto,  é  importante  lembrar  que  a  causalidade,  especialmente  no  contexto  das séries temporais, pode ser complexa e multifacetadae o simples fato de uma variável preceder outra no tempo não garante uma relação de causa e efeito. Os pesquisadores devem usar o teste de  Granger  e  outras  ferramentas  estatísticas  como  um  de  vários  métodos  para  entender  a relação entre diferentes variáveis.

# %%
# Imports
import numpy as np
import pandas as pd
from statsmodels.tsa.stattools import grangercausalitytests

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Michelle Bouhid" --iversions
# Out:
# Author: Michelle Bouhid
#
# matplotlib : 3.7.1
# numpy      : 1.23.5
# seaborn    : 0.11.2
# statsmodels: 0.13.2
# pandas     : 1.5.3

# %%
# Configurando a semente aleatória para reprodutibilidade
np.random.seed(0)

# Gerando duas séries temporais aleatórias
x = np.random.normal(0, 1, 100)
y = np.random.normal(0, 1, 100)

# Criando um DataFrame
df = pd.DataFrame({'x': x, 'y': y})

# Aplicando o teste de causalidade de Granger
# Verbose mostra tudo que o teste está fazendo, padrão é overbose = True
gc_results = grangercausalitytests(df[['x', 'y']], maxlag = 2, verbose = False)

# Mostrando os resultados
for lag, result in gc_results.items():
    pvalue = result[0]['ssr_ftest'][1]
    print(f'Lag: {lag}, Valor-p: {pvalue}')
# Out:
# Lag: 1, Valor-p: 0.5990992737078038
# Lag: 2, Valor-p: 0.8632343343183454

# %% [markdown]
# No código acima, primeiro criamos duas séries temporais aleatórias x e y, que são independentes uma da outra. Em seguida, usamos a função grangercausalitytests do pacote statsmodels para executar o teste de causalidade de Granger, com um máximo de 2 lags. O resultado deste teste é um dicionário de estatísticas do teste, das quais estamos interessados no valor-p do teste F.
#
# O valor-p é a probabilidade de que a hipótese nula seja verdadeira. No contexto do teste de Granger, a hipótese nula é que os coeficientes correspondentes aos valores passados de x são zero, ou seja, que x não causa y. Se o valor-p for pequeno (geralmente, menor que 0,05 é considerado significativo), então rejeitamos a hipótese nula e concluímos que x causa y.
#
# Neste exemplo, uma vez que x e y são independentes, esperamos que o valor-p seja grande e não possamos rejeitar a hipótese nula.
#
# Observe que o **teste de Granger assume que as séries temporais são estacionárias.** Se você estiver trabalhando com séries temporais não estacionárias, pode ser necessário primeiro diferenciá-las ou transformá-las de alguma outra maneira para torná-las estacionárias antes de realizar o teste de Granger.

# %%
import numpy as np
from statsmodels.tsa.stattools import grangercausalitytests

# Configurar parâmetros
np.random.seed(42)  # para resultados consistentes
n = 200  # número de observações
max_lag = 3

# Gerar a série X como um ruído branco
X = np.random.normal(size = (n,))

# Gerar a série Y como uma combinação linear dos valores passados e do valor atual de X
Y = np.zeros_like(X)
for t in range(1, n):
    Y[t] = X[t] + 0.5 * X[t-1] + np.random.normal()

# Reorganizar em uma matriz 2D para o teste de Granger
XY = np.column_stack([X, Y])

# Realizar o teste de Granger
gc_res = grangercausalitytests(XY, maxlag = max_lag)

print("\n")

# Mostrando os resultados
for lag, result in gc_res.items():
    pvalue = result[0]['ssr_ftest'][1]
    print(f'Lag: {lag}, Valor-p: {pvalue}')
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2241  , p=0.6365  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=0.2275  , p=0.6334  , df=1
# likelihood ratio test: chi2=0.2274  , p=0.6335  , df=1
# parameter F test:         F=0.2241  , p=0.6365  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0246  , p=0.9757  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=0.0506  , p=0.9750  , df=2
# likelihood ratio test: chi2=0.0506  , p=0.9750  , df=2
# parameter F test:         F=0.0246  , p=0.9757  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.9559  , p=0.0337  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=9.1944  , p=0.0268  , df=3
# likelihood ratio test: chi2=8.9863  , p=0.0295  , df=3
# parameter F test:         F=2.9559  , p=0.0337  , df_denom=190, df_num=3
#
#
# Lag: 1, Valor-p: 0.636479067674594
# ...

# %% [markdown]
# Conclusão: Somente no lag 3 foi possível estabelecer a relação de causa entre X e Y, com valores passados de X ajudando a prever valores futuros de Y (além dos próprios valores passados de Y, ié como os valores foram deslocados no tempo, além do X, Y tb ajuda a prever o valor futuro de Y).

# %% [markdown]
# ## Correlação Cruzada e Interpretação do Gráfico

# %% [markdown]
# A correlação cruzada **é uma medida da similaridade de duas séries temporais como função do deslocamento aplicado a uma delas**. É comumente usada para encontrar padrões repetidos em uma série em relação a outra série, ou para identificar o lag entre as séries.
#
# Vejamos um exemplo.

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Michelle Bouhid" --iversions
# Out:
# Author: Michelle Bouhid
#
# matplotlib : 3.7.1
# numpy      : 1.23.5
# seaborn    : 0.11.2
# statsmodels: 0.13.2
# pandas     : 1.5.3

# %%
# Configurando a semente aleatória para reprodutibilidade
np.random.seed(0)

# Gerando duas séries temporais, onde a série y é uma versão deslocada e ruidosa da série x
x = np.linspace(0, 10, 100)
y = x + np.random.normal(0, 1, 100) + 5.0

# Calculando a correlação cruzada
# A fç same, centraliza o resultado
correlation = np.correlate(y - np.mean(y), x - np.mean(x), mode = 'same')

# Normalizando o resultado
correlation = correlation / (np.std(y) * np.std(x) * len(x))

# Encontrando o máximo de correlação
lag_max_corr = np.argmax(correlation)

# Plotando a correlação cruzada
plt.figure(figsize=(10, 5))
plt.plot(correlation)
plt.axvline(lag_max_corr, color = 'r', linestyle = '--')
plt.title('Correlação Cruzada')
plt.xlabel('Lag')
plt.ylabel('Correlação')
plt.show()

# %% [markdown]
# Nesse exemplo, y é uma versão deslocada de x com algum ruído adicionado. A correlação cruzada é máxima quando as duas séries estão alinhadas, ou seja, no lag que usamos para deslocar a série y em relação à série x.
#
# O gráfico de correlação cruzada mostra a correlação para diferentes lags. A linha pontilhada vermelha indica o lag no qual a correlação é máxima. Nesse caso, o lag de máximo de correlação deve estar perto do meio do gráfico, já que usamos o modo 'same' na função np.correlate, que centraliza o resultado.
#
# Observe que, na prática, quando se trabalha com séries temporais reais, pode ser necessário pré-processar os dados antes de calcular a correlação cruzada, por exemplo, para remover uma tendência ou para tornar as séries estacionárias.
